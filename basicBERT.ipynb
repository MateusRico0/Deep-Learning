# %% [markdown]
# # Imports

# %%
from sentence_transformers import SentenceTransformer
import tensorflow_datasets as tfds

# %% [markdown]
# # Load Df

# %%
df = tfds.load('movielens/100k-ratings', split='train')
df = tfds.as_dataframe(df)

df = df.head(10000)
df.head()
# Out:
# 2025-07-27 21:31:04.658416: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
#    bucketized_user_age movie_genres movie_id  \
# 0                 45.0          [7]   b'357'
# 1                 25.0      [4, 14]   b'709'
# 2                 18.0          [4]   b'412'
# 3                 50.0       [5, 7]    b'56'
# 4                 50.0     [10, 16]   b'895'
#
#                                  movie_title  raw_user_age  timestamp  \
# 0  b"One Flew Over the Cuckoo's Nest (1975)"          46.0  879024327
# 1                b'Strictly Ballroom (1992)'          32.0  875654590
# 2             b'Very Brady Sequel, A (1996)'          24.0  882075110
# 3                     b'Pulp Fiction (1994)'          50.0  883326919
# 4                         b'Scream 2 (1997)'          55.0  891409199
#
#    user_gender user_id  user_occupation_label user_occupation_text  \
# 0         True  b'138'                      4            b'doctor'
# 1         True   b'92'                      5     b'entertainment'
# 2         True  b'301'                     17           b'student'
# 3         True   b'60'                      4        b'healthcare'
# 4         True  b'197'                     18        b'technician'
#
#    user_rating user_zip_code
# 0          4.0      b'53211'
# 1          2.0      b'80525'
# 2          4.0      b'55439'
# 3          4.0      b'06472'
# 4          3.0      b'75094'

# %% [markdown]
# ## Processing

# %%
df.drop(['bucketized_user_age','movie_id','raw_user_age','user_occupation_text','timestamp','user_gender','user_occupation_label','user_zip_code'], axis=1,inplace=True)

df['user_id'] = df['user_id'].apply(lambda x: x.decode('utf-8')) # retirar o b'' das string
df['user_rating'] = df['user_rating'] / 10 # normalizar entre 0 e 1

# %%
genre_dict = {
    0: 'Action',
    1: 'Drama',
    2: 'Comedy',
    3: 'Thriller',
    4: 'Romance',
    5: 'Sci-Fi',
    6: 'Fantasy',
    7: 'Documentary',
    8: 'Horror',
    9: 'Adventure',
    10: 'Animation',
    11: 'Biography',
    12: 'Crime',
    13: 'Family',
    14: 'History',
    15: 'Music',
    16: 'Mystery',
    17: 'Sport',
    18: 'War',
    19: 'Western'
}

df['movie_genres'] = df['movie_genres'].apply(lambda x: [genre_dict[i] for i in x])
df.head(10)
# Out:
#                          movie_genres  \
# 0                       [Documentary]
# 1                  [Romance, History]
# 2                           [Romance]
# 3               [Sci-Fi, Documentary]
# 4                [Animation, Mystery]
# 5              [Documentary, Mystery]
# 6  [Comedy, Thriller, Romance, Crime]
# 7           [Action, Sci-Fi, History]
# 8                           [Romance]
# 9         [Action, Drama, Music, War]
#
#                                  movie_title user_id  user_rating
# 0  b"One Flew Over the Cuckoo's Nest (1975)"     138          0.4
# 1                b'Strictly Ballroom (1992)'      92          0.2
# 2             b'Very Brady Sequel, A (1996)'     301          0.4
# 3                     b'Pulp Fiction (1994)'      60          0.4
# 4                         b'Scream 2 (1997)'     197          0.3
# 5                            b'Crash (1996)'     601          0.4
# 6                          b'Aladdin (1992)'     710          0.3
# 7                     b'True Romance (1993)'     833          0.2
# 8                      b'Bob Roberts (1992)'     916          0.5
# 9                b'Starship Troopers (1997)'     940          0.2

# %%
def safe_decode(value):
    if isinstance(value, bytes): 
        return value.decode('utf-8')
    return value  

# Combining columns to create more meaningful embeddings
df['title_and_genres'] = df.apply(lambda row: safe_decode(row['movie_title']) + " - " + ', '.join(row['movie_genres']), axis=1)
df.head()
# Out:
#             movie_genres                                movie_title user_id  \
# 0          [Documentary]  b"One Flew Over the Cuckoo's Nest (1975)"     138
# 1     [Romance, History]                b'Strictly Ballroom (1992)'      92
# 2              [Romance]             b'Very Brady Sequel, A (1996)'     301
# 3  [Sci-Fi, Documentary]                     b'Pulp Fiction (1994)'      60
# 4   [Animation, Mystery]                         b'Scream 2 (1997)'     197
#
#    user_rating                                   title_and_genres
# 0          0.4  One Flew Over the Cuckoo's Nest (1975) - Docum...
# 1          0.2        Strictly Ballroom (1992) - Romance, History
# 2          0.4              Very Brady Sequel, A (1996) - Romance
# 3          0.4          Pulp Fiction (1994) - Sci-Fi, Documentary
# 4          0.3               Scream 2 (1997) - Animation, Mystery

# %%
df['user_id'] = df['user_id'].astype(int)
df.head()
# Out:
#             movie_genres                                movie_title  user_id  \
# 0          [Documentary]  b"One Flew Over the Cuckoo's Nest (1975)"      138
# 1     [Romance, History]                b'Strictly Ballroom (1992)'       92
# 2              [Romance]             b'Very Brady Sequel, A (1996)'      301
# 3  [Sci-Fi, Documentary]                     b'Pulp Fiction (1994)'       60
# 4   [Animation, Mystery]                         b'Scream 2 (1997)'      197
#
#    user_rating                                   title_and_genres
# 0          0.4  One Flew Over the Cuckoo's Nest (1975) - Docum...
# 1          0.2        Strictly Ballroom (1992) - Romance, History
# 2          0.4              Very Brady Sequel, A (1996) - Romance
# 3          0.4          Pulp Fiction (1994) - Sci-Fi, Documentary
# 4          0.3               Scream 2 (1997) - Animation, Mystery

# %% [markdown]
# # Model

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")

# %% [markdown]
# ## Embedding generator

# %%
df['embeddings'] = list(model.encode(df['title_and_genres']))

# %%
df.head(10)
# Out:
#                          movie_genres  \
# 0                       [Documentary]
# 1                  [Romance, History]
# 2                           [Romance]
# 3               [Sci-Fi, Documentary]
# 4                [Animation, Mystery]
# 5              [Documentary, Mystery]
# 6  [Comedy, Thriller, Romance, Crime]
# 7           [Action, Sci-Fi, History]
# 8                           [Romance]
# 9         [Action, Drama, Music, War]
#
#                                  movie_title  user_id  user_rating  \
# 0  b"One Flew Over the Cuckoo's Nest (1975)"      138          0.4
# 1                b'Strictly Ballroom (1992)'       92          0.2
# 2             b'Very Brady Sequel, A (1996)'      301          0.4
# 3                     b'Pulp Fiction (1994)'       60          0.4
# 4                         b'Scream 2 (1997)'      197          0.3
# 5                            b'Crash (1996)'      601          0.4
# 6                          b'Aladdin (1992)'      710          0.3
# 7                     b'True Romance (1993)'      833          0.2
# 8                      b'Bob Roberts (1992)'      916          0.5
# 9                b'Starship Troopers (1997)'      940          0.2
#
#                                     title_and_genres  \
# 0  One Flew Over the Cuckoo's Nest (1975) - Docum...
# 1        Strictly Ballroom (1992) - Romance, History
# 2              Very Brady Sequel, A (1996) - Romance
# 3          Pulp Fiction (1994) - Sci-Fi, Documentary
# 4               Scream 2 (1997) - Animation, Mystery
# 5                Crash (1996) - Documentary, Mystery
# 6  Aladdin (1992) - Comedy, Thriller, Romance, Crime
# 7      True Romance (1993) - Action, Sci-Fi, History
# 8                       Bob Roberts (1992) - Romance
# 9  Starship Troopers (1997) - Action, Drama, Musi...
#
#                                           embeddings
# 0  [-0.031615485, 0.016313665, -0.019859074, 0.05...
# 1  [0.005666763, -0.0066977255, -0.030158766, -0....
# 2  [-0.02939043, -0.0384848, -0.02393693, -0.0078...
# 3  [-0.05960273, -0.036336366, -0.06602257, -0.01...
# 4  [-0.0460111, -0.01660724, -0.008522717, 0.0194...
# 5  [-0.007400912, 0.021577645, 0.0022665262, 0.02...
# 6  [-0.044823356, 0.039115388, -0.024226058, -0.0...
# 7  [-0.10908171, -0.043817002, 0.022998724, 0.077...
# 8  [-0.025987634, 0.017029107, -0.07255637, -0.02...
# 9  [-0.059337005, -0.075234905, -0.032056466, -0....
